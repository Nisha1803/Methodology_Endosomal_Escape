# %%
# Separating Channels

# %%
# !pip install --upgrade opencv-python

# %%
# import nbformat
# from nbconvert import PythonExporter

# # Load the notebook

# with open('C:\\Users\\fnisha\\Box\\AB-Cook-Nisha Research\\Endosomal_codes\\STEP1_exp_data.ipynb') as f:
#     nb = nbformat.read(f, as_version=4)

# # Convert to Python script
# exporter = PythonExporter()
# script, _ = exporter.from_notebook_node(nb)

# # Save to .py file
# with open('C:\\Users\\fnisha\\Box\\AB-Cook-Nisha Research\\Endosomal_codes\\STEP1_exp_data.py', 'w') as f:
#     f.write(script)

# %% [markdown]
# # Using Otsu to separate Channels on all of Experimental Data

# %%
import os
import cv2
import numpy as np
import skimage.io
from skimage.filters import threshold_otsu
import csv

def count_special_red_pixels(image):
    # Ensure the image was provided
    if image is None:
        raise ValueError("Image not provided")

    # Split the image into its R, G, B channels
    red_channel = image[:, :, 0]
    green_channel = image[:, :, 1]
    blue_channel = image[:, :, 2]

    # Segment each channel using Otsu's threshold
    red_threshold = threshold_otsu(red_channel)
    green_threshold = threshold_otsu(green_channel)
    blue_threshold = threshold_otsu(blue_channel)

    # Create binary masks for each channel
    red_mask = red_channel > red_threshold
    green_mask_off = green_channel <= green_threshold  # We want green to be "off", so we use <= threshold
    blue_mask_off = blue_channel <= blue_threshold
    red_mask_off = red_channel <= red_threshold
    blue_mask = blue_channel > blue_threshold
    green_mask = green_channel > green_threshold

    # Find the pixels where red is on, blue is on, and green is off
    special_red_blue_pixels_mask = red_mask & blue_mask & green_mask_off
    # Find the pixels where red is on, and green is on and blue is off
    special_red_green_pixels_mask = red_mask & green_mask
    # Find the pixels where red is on, and green is off and blue is off
    special_red_no_green_blue = red_mask & green_mask_off & blue_mask_off
    # Find the pixels where red is on, and green is on and blue is on
    special_red_green_blue_pixels_mask = red_mask & green_mask & blue_mask
    # Find the pixels where red is on, and green is off
    special_red_outside_green_pixels_mask = red_mask & green_mask_off
    # Total red pixels
    special_red = red_mask

    # Count these special pixels
    count_red_outside_green = np.sum(special_red_outside_green_pixels_mask)
    count_red_on_blue = np.sum(special_red_blue_pixels_mask) #only on blue not green
    count_red_on_green = np.sum(special_red_green_pixels_mask) # only on green not blue
    count_red_not_greenblue = np.sum(special_red_no_green_blue) #only red no blue and no green
    count_red_on_blue_and_green = np.sum(special_red_green_blue_pixels_mask)
    count_red = np.sum(special_red)

    return count_red_on_green, count_red_outside_green, count_red

# %% [markdown]
# # Converting image data to csv data

# %%
import os
import csv
import skimage.io

def read_images_from_folders(root_directory):
    # Fixed the path to point to a file rather than a directory
    output_csv_path = 'C:\\Users\\fnisha\\Box\\AB-Cook-Nisha Research\\image_analysis_ovary\\80_raw_edit_endosomal_values_with_ratio.csv'


    # Check if the file already exists
    file_exists = os.path.isfile(output_csv_path)

    # Open CSV file in append mode
    with open(output_csv_path, 'a', newline='') as csvfile:
        csv_writer = csv.writer(csvfile, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)

        # Write the header row if the file doesn't exist
        if not file_exists:
            csv_writer.writerow(["Main Folder", "Subfolder", "Image Name", "Red on Green Count", "Red outside Green Count", "Total Red Count"])

        # Iterate through all folders and subfolders in the root directory
        for dirpath, dirnames, filenames in os.walk(root_directory):
            # Get the relative path from the root directory
            rel_path = os.path.relpath(dirpath, root_directory)
            # Split the relative path into parts
            path_parts = rel_path.split(os.sep)

            # Skip processing if we are in the root directory or if the path doesn't have at least two parts
            if len(path_parts) < 2:
                continue

            main_folder = path_parts[0]
            subfolder = path_parts[1]

            for filename in filenames:
                # Check for .tif image file extensions
                if filename.endswith('.tif'):
                    file_path = os.path.join(dirpath, filename)
                    img = skimage.io.imread(file_path)
                    count_red_on_green, count_red_outside_green, red_total = count_special_red_pixels(img)

                    # Write individual image data to CSV
                    csv_writer.writerow([main_folder, subfolder, filename, count_red_on_green, count_red_outside_green, red_total])

                    # Printing to console (optional)
                    print(f"Main Folder: {main_folder}")
                    print(f"Subfolder: {subfolder}")
                    print(f"Image Name: {filename}")
                    print(f"Red on Green Count: {count_red_on_green}")
                    print(f"Red outside Green Count: {count_red_outside_green}")
                    print(f"Total Red Count: {red_total}")
                    print("----------")


# Example usage
root_directory = 'C:\\Users\\fnisha\\Box\\AB-Cook-Nisha Research\\image_analysis_ovary\\80'
read_images_from_folders(root_directory)
# Out:
# Main Folder: 80_background_edit
# Subfolder: T0001
# Image Name: T0001_combined.tif
# Red on Green Count: 2969
# Red outside Green Count: 6736
# Total Red Count: 9705
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0002
# Image Name: T0002_combined.tif
# Red on Green Count: 2849
# Red outside Green Count: 8205
# Total Red Count: 11054
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0003
# Image Name: T0003_combined.tif
# Red on Green Count: 1388
# Red outside Green Count: 5828
# Total Red Count: 7216
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0004
# Image Name: T0004_combined.tif
# Red on Green Count: 2857
# Red outside Green Count: 8059
# Total Red Count: 10916
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0005
# Image Name: T0005_combined.tif
# Red on Green Count: 2894
# Red outside Green Count: 10815
# Total Red Count: 13709
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0006
# Image Name: T0006_combined.tif
# Red on Green Count: 3384
# Red outside Green Count: 12069
# Total Red Count: 15453
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0007
# Image Name: T0007_combined.tif
# Red on Green Count: 5481
# Red outside Green Count: 21613
# Total Red Count: 27094
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0008
# Image Name: T0008_combined.tif
# Red on Green Count: 2814
# Red outside Green Count: 14828
# Total Red Count: 17642
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0009
# Image Name: T0009_combined.tif
# Red on Green Count: 4080
# Red outside Green Count: 18197
# Total Red Count: 22277
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0010
# Image Name: T0010_combined.tif
# Red on Green Count: 6134
# Red outside Green Count: 25229
# Total Red Count: 31363
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0011
# Image Name: T0011_combined.tif
# Red on Green Count: 5210
# Red outside Green Count: 26098
# Total Red Count: 31308
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0012
# Image Name: T0012_combined.tif
# Red on Green Count: 5899
# Red outside Green Count: 27638
# Total Red Count: 33537
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0013
# Image Name: T0013_combined.tif
# Red on Green Count: 12223
# Red outside Green Count: 42896
# Total Red Count: 55119
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0014
# Image Name: T0014_combined.tif
# Red on Green Count: 5250
# Red outside Green Count: 24994
# Total Red Count: 30244
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0015
# Image Name: T0015_combined.tif
# Red on Green Count: 6613
# Red outside Green Count: 27770
# Total Red Count: 34383
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0016
# Image Name: T0016_combined.tif
# Red on Green Count: 6754
# Red outside Green Count: 28569
# Total Red Count: 35323
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0017
# Image Name: T0017_combined.tif
# Red on Green Count: 6924
# Red outside Green Count: 28759
# Total Red Count: 35683
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0018
# Image Name: T0018_combined.tif
# Red on Green Count: 5856
# Red outside Green Count: 29283
# Total Red Count: 35139
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0019
# Image Name: T0019_combined.tif
# Red on Green Count: 6070
# Red outside Green Count: 28012
# Total Red Count: 34082
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0020
# Image Name: T0020_combined.tif
# Red on Green Count: 6259
# Red outside Green Count: 28980
# Total Red Count: 35239
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0021
# Image Name: T0021_combined.tif
# Red on Green Count: 7318
# Red outside Green Count: 29066
# Total Red Count: 36384
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0022
# Image Name: T0022_combined.tif
# Red on Green Count: 7086
# Red outside Green Count: 31158
# Total Red Count: 38244
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0023
# Image Name: T0023_combined.tif
# Red on Green Count: 8103
# Red outside Green Count: 34688
# Total Red Count: 42791
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0024
# Image Name: T0024_combined.tif
# Red on Green Count: 9229
# Red outside Green Count: 34577
# Total Red Count: 43806
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0025
# Image Name: T0025_combined.tif
# Red on Green Count: 7838
# Red outside Green Count: 31140
# Total Red Count: 38978
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0026
# Image Name: T0026_combined.tif
# Red on Green Count: 9819
# Red outside Green Count: 36325
# Total Red Count: 46144
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0027
# Image Name: T0027_combined.tif
# Red on Green Count: 9750
# Red outside Green Count: 36074
# Total Red Count: 45824
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0028
# Image Name: T0028_combined.tif
# Red on Green Count: 10554
# Red outside Green Count: 38991
# Total Red Count: 49545
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0029
# Image Name: T0029_combined.tif
# Red on Green Count: 11473
# Red outside Green Count: 39954
# Total Red Count: 51427
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0030
# Image Name: T0030_combined.tif
# Red on Green Count: 14852
# Red outside Green Count: 46010
# Total Red Count: 60862
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0031
# Image Name: T0031_combined.tif
# Red on Green Count: 14103
# Red outside Green Count: 43063
# Total Red Count: 57166
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0032
# Image Name: T0032_combined.tif
# Red on Green Count: 13473
# Red outside Green Count: 44355
# Total Red Count: 57828
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0033
# Image Name: T0033_combined.tif
# Red on Green Count: 13328
# Red outside Green Count: 44280
# Total Red Count: 57608
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0034
# Image Name: T0034_combined.tif
# Red on Green Count: 12139
# Red outside Green Count: 40636
# Total Red Count: 52775
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0035
# Image Name: T0035_combined.tif
# Red on Green Count: 13952
# Red outside Green Count: 47050
# Total Red Count: 61002
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0036
# Image Name: T0036_combined.tif
# Red on Green Count: 14840
# Red outside Green Count: 46994
# Total Red Count: 61834
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0037
# Image Name: T0037_combined.tif
# Red on Green Count: 15978
# Red outside Green Count: 48923
# Total Red Count: 64901
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0038
# Image Name: T0038_combined.tif
# Red on Green Count: 14778
# Red outside Green Count: 51124
# Total Red Count: 65902
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0039
# Image Name: T0039_combined.tif
# Red on Green Count: 14611
# Red outside Green Count: 43844
# Total Red Count: 58455
# ----------
# Main Folder: 80_background_edit
# Subfolder: T0040
# Image Name: T0040_combined.tif
# Red on Green Count: 15479
# Red outside Green Count: 50528
# Total Red Count: 66007
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0001
# Image Name: T001 Green and Red Overlay.tif
# Red on Green Count: 554
# Red outside Green Count: 1092
# Total Red Count: 1646
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0001
# Image Name: T001 Red and Green Overlay.tif
# Red on Green Count: 554
# Red outside Green Count: 1092
# Total Red Count: 1646
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0001
# Image Name: T001 Green and Red Overlay-checkpoint.tif
# Red on Green Count: 554
# Red outside Green Count: 1092
# Total Red Count: 1646
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0002
# Image Name: T002 Red and Green Overlay.tif
# Red on Green Count: 445
# Red outside Green Count: 1167
# Total Red Count: 1612
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0003
# Image Name: T0003 Red and Green Overlay.tif
# Red on Green Count: 517
# Red outside Green Count: 2216
# Total Red Count: 2733
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0004
# Image Name: T0004 Red and Green Overlay.tif
# Red on Green Count: 619
# Red outside Green Count: 2217
# Total Red Count: 2836
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0005
# Image Name: T0005 Red and Green Overlay.tif
# Red on Green Count: 455
# Red outside Green Count: 2992
# Total Red Count: 3447
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0006
# Image Name: T0006 Red and Green Overlay.tif
# Red on Green Count: 795
# Red outside Green Count: 3803
# Total Red Count: 4598
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0007
# Image Name: T0007 Red and Green Overlay.tif
# Red on Green Count: 952
# Red outside Green Count: 5353
# Total Red Count: 6305
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0008
# Image Name: T0008 Red and Green Overlay.tif
# Red on Green Count: 882
# Red outside Green Count: 6760
# Total Red Count: 7642
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0009
# Image Name: T0009 Red and Green Overlay.tif
# Red on Green Count: 1574
# Red outside Green Count: 9370
# Total Red Count: 10944
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0010
# Image Name: T0010 Red and Green Overlay.tif
# Red on Green Count: 2195
# Red outside Green Count: 11487
# Total Red Count: 13682
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0011
# Image Name: T0011 Red and Green Overlay.tif
# Red on Green Count: 2316
# Red outside Green Count: 14007
# Total Red Count: 16323
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0014
# Image Name: T0014 Red and Green Overlay.tif
# Red on Green Count: 4320
# Red outside Green Count: 19288
# Total Red Count: 23608
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0015
# Image Name: T0015 Red and Green Overlay.tif
# Red on Green Count: 4586
# Red outside Green Count: 21012
# Total Red Count: 25598
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0016
# Image Name: T0016 Red and Green Overlay.tif
# Red on Green Count: 4775
# Red outside Green Count: 21389
# Total Red Count: 26164
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0017
# Image Name: T0017 Red and Green Overlay.tif
# Red on Green Count: 4891
# Red outside Green Count: 22175
# Total Red Count: 27066
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0018
# Image Name: T0018 Red and Green Overlay.tif
# Red on Green Count: 4032
# Red outside Green Count: 22485
# Total Red Count: 26517
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0019
# Image Name: T0019 Red and Green Overlay.tif
# Red on Green Count: 4318
# Red outside Green Count: 21438
# Total Red Count: 25756
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0020
# Image Name: T0020 Red and Green Overlay.tif
# Red on Green Count: 4208
# Red outside Green Count: 22624
# Total Red Count: 26832
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0021
# Image Name: T0021 Red and Green Overlay.tif
# Red on Green Count: 4782
# Red outside Green Count: 22677
# Total Red Count: 27459
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0022
# Image Name: T0022 Red and Green Overlay.tif
# Red on Green Count: 4699
# Red outside Green Count: 23954
# Total Red Count: 28653
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0023
# Image Name: T0023 Red and Green Overlay.tif
# Red on Green Count: 4353
# Red outside Green Count: 23573
# Total Red Count: 27926
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0024
# Image Name: T0024 Red and Green Overlay.tif
# Red on Green Count: 5335
# Red outside Green Count: 23514
# Total Red Count: 28849
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0025
# Image Name: T0025 Red and Green Overlay.tif
# Red on Green Count: 6083
# Red outside Green Count: 23349
# Total Red Count: 29432
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0026
# Image Name: T0026 Red and Green Overlay.tif
# Red on Green Count: 5569
# Red outside Green Count: 24670
# Total Red Count: 30239
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0027
# Image Name: T0027 Red and Green Overlay.tif
# Red on Green Count: 5488
# Red outside Green Count: 24571
# Total Red Count: 30059
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0028
# Image Name: T0028 Red and Green Overlay.tif
# Red on Green Count: 5655
# Red outside Green Count: 24015
# Total Red Count: 29670
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0029
# Image Name: T0029 Red and Green Overlay.tif
# Red on Green Count: 6390
# Red outside Green Count: 27335
# Total Red Count: 33725
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0030
# Image Name: T0030 Red and Green Overlay.tif
# Red on Green Count: 6385
# Red outside Green Count: 27317
# Total Red Count: 33702
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0031
# Image Name: T0031 Red and Green Overlay.tif
# Red on Green Count: 7837
# Red outside Green Count: 28913
# Total Red Count: 36750
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0032
# Image Name: T0032 Red and Green Overlay.tif
# Red on Green Count: 7226
# Red outside Green Count: 30904
# Total Red Count: 38130
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0033
# Image Name: T0033 Red and Green Overlay.tif
# Red on Green Count: 7769
# Red outside Green Count: 29645
# Total Red Count: 37414
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0034
# Image Name: T0034 Red and Green Overlay.tif
# Red on Green Count: 7805
# Red outside Green Count: 31610
# Total Red Count: 39415
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0035
# Image Name: T0035 Red and Green Overlay.tif
# Red on Green Count: 7256
# Red outside Green Count: 32334
# Total Red Count: 39590
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0036
# Image Name: T0036 Red and Green Overlay.tif
# Red on Green Count: 8455
# Red outside Green Count: 31680
# Total Red Count: 40135
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0037
# Image Name: T0037 Red and Green Overlay.tif
# Red on Green Count: 9369
# Red outside Green Count: 32813
# Total Red Count: 42182
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0038
# Image Name: T0038 Red and Green Overlay.tif
# Red on Green Count: 8892
# Red outside Green Count: 33975
# Total Red Count: 42867
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0039
# Image Name: T0039 Red and Green Overlay.tif
# Red on Green Count: 10816
# Red outside Green Count: 33475
# Total Red Count: 44291
# ----------
# Main Folder: 80_edited_images
# Subfolder: T0040
# Image Name: T0040 Red and Green Overlay.tif
# Red on Green Count: 8791
# Red outside Green Count: 33649
# Total Red Count: 42440
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0001
# Image Name: Image_T0001_XY01_Z002_Overlay.tif
# Red on Green Count: 168015
# Red outside Green Count: 578836
# Total Red Count: 746851
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0002
# Image Name: Image_T0002_XY01_Z002_Overlay.tif
# Red on Green Count: 149290
# Red outside Green Count: 593499
# Total Red Count: 742789
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0003
# Image Name: Image_T0003_XY01_Z002_Overlay.tif
# Red on Green Count: 153353
# Red outside Green Count: 632682
# Total Red Count: 786035
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0004
# Image Name: Image_T0004_XY01_Z002_Overlay.tif
# Red on Green Count: 160543
# Red outside Green Count: 640030
# Total Red Count: 800573
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0005
# Image Name: Image_T0005_XY01_Z002_Overlay.tif
# Red on Green Count: 162014
# Red outside Green Count: 658437
# Total Red Count: 820451
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0006
# Image Name: Image_T0006_XY01_Z002_Overlay.tif
# Red on Green Count: 181337
# Red outside Green Count: 666708
# Total Red Count: 848045
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0007
# Image Name: Image_T0007_XY01_Z002_Overlay.tif
# Red on Green Count: 184157
# Red outside Green Count: 683262
# Total Red Count: 867419
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0008
# Image Name: Image_T0008_XY01_Z002_Overlay.tif
# Red on Green Count: 182564
# Red outside Green Count: 685592
# Total Red Count: 868156
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0009
# Image Name: Image_T0009_XY01_Z002_Overlay.tif
# Red on Green Count: 181445
# Red outside Green Count: 707049
# Total Red Count: 888494
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0010
# Image Name: Image_T0010_XY01_Z002_Overlay.tif
# Red on Green Count: 181241
# Red outside Green Count: 673912
# Total Red Count: 855153
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0011
# Image Name: Image_T0011_XY01_Z002_Overlay.tif
# Red on Green Count: 165893
# Red outside Green Count: 705785
# Total Red Count: 871678
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0012
# Image Name: Image_T0012_XY01_Z002_Overlay.tif
# Red on Green Count: 149532
# Red outside Green Count: 711880
# Total Red Count: 861412
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0013
# Image Name: Image_T0013_XY01_Z002_Overlay.tif
# Red on Green Count: 164664
# Red outside Green Count: 694951
# Total Red Count: 859615
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0014
# Image Name: Image_T0014_XY01_Z002_Overlay.tif
# Red on Green Count: 174497
# Red outside Green Count: 682961
# Total Red Count: 857458
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0015
# Image Name: Image_T0015_XY01_Z002_Overlay.tif
# Red on Green Count: 172684
# Red outside Green Count: 682150
# Total Red Count: 854834
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0016
# Image Name: Image_T0016_XY01_Z002_Overlay.tif
# Red on Green Count: 159565
# Red outside Green Count: 698985
# Total Red Count: 858550
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0017
# Image Name: Image_T0017_XY01_Z002_Overlay.tif
# Red on Green Count: 170612
# Red outside Green Count: 700831
# Total Red Count: 871443
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0018
# Image Name: Image_T0018_XY01_Z002_Overlay.tif
# Red on Green Count: 160567
# Red outside Green Count: 706862
# Total Red Count: 867429
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0019
# Image Name: Image_T0019_XY01_Z002_Overlay.tif
# Red on Green Count: 159373
# Red outside Green Count: 706028
# Total Red Count: 865401
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0020
# Image Name: Image_T0020_XY01_Z002_Overlay.tif
# Red on Green Count: 145310
# Red outside Green Count: 717355
# Total Red Count: 862665
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0021
# Image Name: Image_T0021_XY01_Z002_Overlay.tif
# Red on Green Count: 156139
# Red outside Green Count: 715404
# Total Red Count: 871543
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0022
# Image Name: Image_T0022_XY01_Z002_Overlay.tif
# Red on Green Count: 155689
# Red outside Green Count: 707772
# Total Red Count: 863461
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0023
# Image Name: Image_T0023_XY01_Z002_Overlay.tif
# Red on Green Count: 154527
# Red outside Green Count: 698250
# Total Red Count: 852777
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0024
# Image Name: Image_T0024_XY01_Z002_Overlay.tif
# Red on Green Count: 145792
# Red outside Green Count: 716341
# Total Red Count: 862133
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0025
# Image Name: Image_T0025_XY01_Z002_Overlay.tif
# Red on Green Count: 136789
# Red outside Green Count: 722049
# Total Red Count: 858838
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0026
# Image Name: Image_T0026_XY01_Z002_Overlay.tif
# Red on Green Count: 135856
# Red outside Green Count: 717806
# Total Red Count: 853662
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0027
# Image Name: Image_T0027_XY01_Z002_Overlay.tif
# Red on Green Count: 144716
# Red outside Green Count: 697378
# Total Red Count: 842094
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0028
# Image Name: Image_T0028_XY01_Z002_Overlay.tif
# Red on Green Count: 142658
# Red outside Green Count: 701236
# Total Red Count: 843894
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0029
# Image Name: Image_T0029_XY01_Z002_Overlay.tif
# Red on Green Count: 140498
# Red outside Green Count: 706478
# Total Red Count: 846976
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0030
# Image Name: Image_T0030_XY01_Z002_Overlay.tif
# Red on Green Count: 140787
# Red outside Green Count: 708544
# Total Red Count: 849331
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0031
# Image Name: Image_T0031_XY01_Z002_Overlay.tif
# Red on Green Count: 161782
# Red outside Green Count: 714562
# Total Red Count: 876344
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0032
# Image Name: Image_T0032_XY01_Z002_Overlay.tif
# Red on Green Count: 150419
# Red outside Green Count: 728318
# Total Red Count: 878737
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0033
# Image Name: Image_T0033_XY01_Z002_Overlay.tif
# Red on Green Count: 152266
# Red outside Green Count: 719920
# Total Red Count: 872186
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0034
# Image Name: Image_T0034_XY01_Z002_Overlay.tif
# Red on Green Count: 163399
# Red outside Green Count: 706877
# Total Red Count: 870276
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0035
# Image Name: Image_T0035_XY01_Z002_Overlay.tif
# Red on Green Count: 160752
# Red outside Green Count: 712366
# Total Red Count: 873118
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0036
# Image Name: Image_T0036_XY01_Z002_Overlay.tif
# Red on Green Count: 176676
# Red outside Green Count: 695777
# Total Red Count: 872453
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0037
# Image Name: Image_T0037_XY01_Z002_Overlay.tif
# Red on Green Count: 178490
# Red outside Green Count: 701792
# Total Red Count: 880282
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0038
# Image Name: Image_T0038_XY01_Z002_Overlay.tif
# Red on Green Count: 178303
# Red outside Green Count: 694240
# Total Red Count: 872543
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0039
# Image Name: Image_T0039_XY01_Z002_Overlay.tif
# Red on Green Count: 172772
# Red outside Green Count: 689044
# Total Red Count: 861816
# ----------
# Main Folder: 80_raw_image_output_folder
# Subfolder: T0040
# Image Name: Image_T0040_XY01_Z002_Overlay.tif
# Red on Green Count: 171392
# Red outside Green Count: 686427
# Total Red Count: 857819
# ----------

# %%
import pandas as pd

# Load the CSV file with raw strings
df = pd.read_csv(r'C:\Users\fnisha\Box\AB-Cook-Nisha Research\image_analysis_ovary\80_raw_edit_endosomal_values_with_ratio.csv')

# Extract the peptide ratio from the "Main Folder" column
# Here, you can modify the logic if needed to parse the "Peptide Ratio"
df['Peptide Ratio'] = df['Main Folder']

# Reordering columns to place 'Peptide Ratio' next to 'Main Folder'
df = df[['Main Folder', 'Peptide Ratio'] + [col for col in df.columns if col not in ['Main Folder', 'Peptide Ratio']]]

# Save the updated DataFrame to a new CSV file
updated_file_with_ratio_path = r'C:\Users\fnisha\Box\AB-Cook-Nisha Research\image_analysis_ovary\80_raw_edit_endosomal_values_with_ratio.csv'
df.to_csv(updated_file_with_ratio_path, index=False)

# Display the updated file path
print(f"Updated file saved to: {updated_file_with_ratio_path}")
# Out:
# Updated file saved to: C:\Users\fnisha\Box\AB-Cook-Nisha Research\image_analysis_ovary\80_raw_edit_endosomal_values_with_ratio.csv

# %% [markdown]
# # Calculating Experimental endosomal escape

# %%
import csv
from collections import defaultdict

def calculate_endosomal_escape(csv_file):
    try:
        # Read the CSV file
        with open(csv_file, 'r') as file:
            reader = csv.reader(file)
            rows = list(reader)

        # Ensure there are rows in the CSV
        if not rows:
            print("The CSV file is empty.")
            return

        # Extract the headers and numeric rows
        headers = rows[0]
        numeric_rows = rows[1:]

        # Identify the column indices for peptide ratio, red outside green count, and red count
        try:
            peptide_ratio_idx = headers.index("Peptide Ratio")
            red_outside_green_idx = headers.index("Red outside Green Count")
            red_count_idx = headers.index("Total Red Count")
        except ValueError as e:
            print(f"Error: Required column headers not found. {e}")
            return

        # Dictionary to store the maximum red count for each peptide ratio
        max_red_count_by_ratio = defaultdict(int)

        # Find the maximum red count for each peptide ratio
        for row in numeric_rows:
            try:
                peptide_ratio = row[peptide_ratio_idx]
                red_count = float(row[red_count_idx]) if row[red_count_idx].strip() else 0.0
                max_red_count_by_ratio[peptide_ratio] = max(max_red_count_by_ratio[peptide_ratio], red_count)
            except (ValueError, IndexError) as e:
                print(f"Skipping invalid row (max red count calculation): {row}. Error: {e}")
                continue

        # Calculate endosomal escape and EFP_in for each row
        for row in numeric_rows:
            try:
                peptide_ratio = row[peptide_ratio_idx]
                red_outside_green_count = float(row[red_outside_green_idx]) if row[red_outside_green_idx].strip() else 0.0
                red_count = float(row[red_count_idx]) if row[red_count_idx].strip() else 0.0
                total_red_last_row = max_red_count_by_ratio.get(peptide_ratio, 0)
                EFP_in = (red_count / total_red_last_row) * 100 if total_red_last_row != 0 else 0
                endosomal_escape = (red_outside_green_count / total_red_last_row) * 100 if total_red_last_row != 0 else 0
                row.append(endosomal_escape)
                row.append(EFP_in)
            except (ValueError, IndexError) as e:
                print(f"Skipping invalid row (calculation): {row}. Error: {e}")
                continue

        # Insert the headers for the new columns
        headers.append("Endosomal Escape%")
        headers.append("EFP_in%")

        # Write the updated rows with the new columns back to the CSV file
        with open(csv_file, 'w', newline='') as file:
            writer = csv.writer(file)
            writer.writerows([headers] + numeric_rows)

        print("CSV file updated successfully.")

    except FileNotFoundError:
        print(f"Error: The file {csv_file} was not found.")
    except Exception as e:
        print(f"An unexpected error occurred: {e}")

# Example usage
csv_file_path = 'C:\\Users\\fnisha\\Box\\AB-Cook-Nisha Research\\image_analysis_ovary\\80_raw_edit_endosomal_values_with_ratio.csv'
calculate_endosomal_escape(csv_file_path)
# Out:
# CSV file updated successfully.

# %% [markdown]
# # Plot Experimental Data

# %%
import os
import csv
import matplotlib.pyplot as plt

def plot_endosomal_escape(csv_file):
    # Read the CSV file
    with open(csv_file, 'r') as file:
        reader = csv.reader(file)
        rows = list(reader)

    # Extract the header and numeric rows
    header = rows[0]
    numeric_rows = rows[1:]

    # Filter rows based on the main folders being '40.0' and '80.0'
    rows_40 = [row for row in numeric_rows if row[0] == '80_edited_images']
    rows_80 = [row for row in numeric_rows if row[0] == '80_raw_image_output_folder']
    rows_801 = [row for row in numeric_rows if row[0] == '80_background_edit']
    rows_copied_80 = [row for row in numeric_rows if row[0] == 'copied_80']
    rows_interpolate_80 = [row for row in numeric_rows if row[0] == 'interpolate_80']

    # Extract endosomal escape values from the filtered rows
    endosomal_escape_40 = [float(row[-2]) for row in rows_40]
    endosomal_escape_80 = [float(row[-2]) for row in rows_80]
    endosomal_escape_801 = [float(row[-2]) for row in rows_801]
    endosomal_escape_802 = [float(row[-2]) for row in rows_interpolate_80]
    endosomal_escape_copied_80 = [float(row[-2]) for row in rows_copied_80]

    # Define time points for plotting
    start_time_40 =45  # Start time in minutes for 40.0 ratio
    time_interval_40 = 5  # Time interval in minutes for 40.0 ratio
    time_points_40 = [(start_time_40 + i * time_interval_40)/60 for i in range(len(endosomal_escape_40))]

    start_time_80 = 45  # Start time in minutes for 80.0 ratio
    time_interval_80 = 5  # Time interval in minutes for 80.0 ratio
    time_points_80 = [(start_time_80 + i * time_interval_80)/60 for i in range(len(endosomal_escape_80))]

    start_time_801 = 45  # Start time in minutes for 80.0 ratio
    time_interval_801 = 5  # Time interval in minutes for 80.0 ratio
    time_points_801 = [(start_time_801 + i * time_interval_801)/60 for i in range(len(endosomal_escape_801))]

    start_time_802 = 45  # Start time in minutes for 80.0 ratio
    time_interval_802 = 5  # Time interval in minutes for 80.0 ratio
    time_points_802 = [(start_time_802 + i * time_interval_802)/60 for i in range(len(endosomal_escape_802))]

    start_time_copied_80 = 45  # Start time in minutes for 80.0 ratio
    time_interval_copied_80 = 5  # Time interval in minutes for 80.0 ratio
    time_points_copied_80 = [(start_time_copied_80 + i * time_interval_copied_80)/60 for i in range(len(endosomal_escape_copied_80))]

    # Plot endosomal escape versus time for both main folders
    plt.plot(time_points_40, endosomal_escape_40, marker='o', linestyle='-', label='Partially edited by model')
    plt.plot(time_points_802, endosomal_escape_802, marker='o', linestyle='-', label='Fully edited by model')
    plt.plot(time_points_copied_80, endosomal_escape_copied_80, marker='o', linestyle='-', label='Fully edited by hand')

    plt.xlabel('Time (hours)')
    plt.ylabel('Endosomal Escape %')
    plt.title('Endosomal Escape over Time')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage

csv_file_path = 'C:\\Users\\fnisha\\Box\\AB-Cook-Nisha Research\\image_analysis_ovary\\80_dataset_with_fixed_cycles.csv'
plot_endosomal_escape(csv_file_path)

# %%
import os
import csv
import matplotlib.pyplot as plt

def plot_endosomal_escape(csv_file):
    # Read the CSV file
    with open(csv_file, 'r') as file:
        reader = csv.reader(file)
        rows = list(reader)

    # Extract the header and numeric rows
    header = rows[0]
    numeric_rows = rows[1:]

    # Filter rows based on the main folders being '40.0' and '80.0'
    rows_40 = [row for row in numeric_rows if row[0] == '80_edited_images']
    rows_80 = [row for row in numeric_rows if row[0] == '80_raw_image_output_folder']
    rows_801 = [row for row in numeric_rows if row[0] == '80_background_edit']
    rows_copied_80 = [row for row in numeric_rows if row[0] == 'copied_80']

    # Extract endosomal escape values from the filtered rows
    endosomal_escape_40 = [float(row[-2]) for row in rows_40]
    endosomal_escape_80 = [float(row[-2]) for row in rows_80]
    endosomal_escape_801 = [float(row[-2]) for row in rows_801]
    endosomal_escape_copied_80 = [float(row[-2]) for row in rows_copied_80]

    # Define time points for plotting
    start_time_40 =45  # Start time in minutes for 40.0 ratio
    time_interval_40 = 5  # Time interval in minutes for 40.0 ratio
    time_points_40 = [(start_time_40 + i * time_interval_40)/60 for i in range(len(endosomal_escape_40))]

    start_time_80 = 45  # Start time in minutes for 80.0 ratio
    time_interval_80 = 5  # Time interval in minutes for 80.0 ratio
    time_points_80 = [(start_time_80 + i * time_interval_80)/60 for i in range(len(endosomal_escape_80))]

    start_time_801 = 45  # Start time in minutes for 80.0 ratio
    time_interval_801 = 5  # Time interval in minutes for 80.0 ratio
    time_points_801 = [(start_time_801 + i * time_interval_801)/60 for i in range(len(endosomal_escape_801))]

    start_time_copied_80 = 45  # Start time in minutes for 80.0 ratio
    time_interval_copied_80 = 5  # Time interval in minutes for 80.0 ratio
    time_points_copied_80 = [(start_time_copied_80 + i * time_interval_copied_80)/60 for i in range(len(endosomal_escape_copied_80))]

    # Plot endosomal escape versus time for both main folders
    plt.plot(time_points_40, endosomal_escape_40, marker='o', linestyle='-', label='80_mask_edit')
    plt.plot(time_points_801, endosomal_escape_801, marker='o', linestyle='-', label='80_background_edit_mask')
    plt.plot(time_points_copied_80, endosomal_escape_copied_80, marker='o', linestyle='-', label='hand edit 80:1')

    plt.xlabel('Time (hours)')
    plt.ylabel('Endosomal Escape %')
    plt.title('Endosomal Escape versus Time for peptide ratio 80:1')
    plt.legend()
    plt.grid(True)
    plt.show()

# Example usage

csv_file_path = 'C:\\Users\\fnisha\\Box\\AB-Cook-Nisha Research\\image_analysis_ovary\\80_raw_edit_endosomal_values_with_ratio.csv'
plot_endosomal_escape(csv_file_path)
